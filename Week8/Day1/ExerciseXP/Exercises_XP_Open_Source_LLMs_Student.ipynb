# %% [markdown]
# # Exercises XP: Open-Source LLM Strategy (Student)
# Use this guided notebook and fill each TODO. Run it in Colab if you prefer; GPU not required unless you try optional model runs.

# %% [markdown]
# ## What you'll learn
# - Identify degrees of openness in LLMs and what each enables.
# - Understand and compare open-source licenses.
# - Assess strengths/trade-offs of open LLMs for specific constraints (CPU, math, multilingual).
# - Evaluate which models fit given hardware and licensing needs.
# - Use open tools/leaderboards to guide model selection.
# - Plan deployment trade-offs (local vs. cloud).

# %% [markdown]
# ## What you will create
# - Comparative LLM openness analysis (table + paragraph + healthcare prompt answer).
# - Licensing compatibility checklist for SaaS products.
# - Quiz-style reflection on LLM selection.
# - Local deployment readiness checklist + upgrade notes.
# - Benchmark-based model match guide.
# - Hardware upgrade plan / cost-benefit comparison (local vs. cloud).

# %% [markdown]
# ## Exercise 1: Open Source Levels Reflection
# **Use:** Fully Open, Weights Released, Architecture Only; model components; fine-tuning/domain adaptation; healthcare compliance.
#
# **Step-by-step**
# 1) Gather definitions for the three openness levels.
# 2) Identify key characteristics (what is open; what you can/cannot do).
# 3) Compare side by side in a table (what's open vs. impact).
# 4) Write a 3?5 sentence comparative paragraph.
# 5) Answer the healthcare prompt (1?2 sentences) about retraining on clinical data.
#
# **Deliverables:** paragraph + healthcare answer.

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "All components (code, weights, data, architecture) are publicly available and can be freely used, modified, and distributed.",
        "what_is_open": ["Training code", "Model weights", "Training data", "Architecture"],
        "what_you_can_do": ["Reproduce training", "Fine-tune for any purpose", "Deploy anywhere", "Examine internals"],
        "what_you_cannot_do": [""],
    },
    "Weights Released": {
        "definition": "Model weights are available, but the training code, data, or exact architecture might be proprietary or less transparent.",
        "what_is_open": ["Model weights"],
        "what_you_can_do": ["Fine-tune on custom data", "Run inference locally", "Integrate into applications"],
        "what_you_cannot_do": ["Reproduce original training", "Modify core architecture easily"],
    },
    "Architecture Only": {
        "definition": "Only the model's architecture (e.g., number of layers, attention mechanisms) is public, without weights or training data.",
        "what_is_open": ["Model architecture (e.g., research paper)"],
        "what_you_can_do": ["Understand the model's design", "Re-implement and train from scratch"],
        "what_you_cannot_do": ["Use pre-trained capabilities", "Fine-tune without extensive training"],
    },
}
open_source_levels

# %%
# TODO: fill the comparison table (keep markdown formatting)
comparison_table = """| Openness level | What's open? | Impact on retraining/modifying |
| --- | --- | --- |
| Fully Open | Training code, weights, data, architecture | Full control; easy to retrain, modify, and adapt deeply |
| Weights Released | Model weights | Can fine-tune and adapt; cannot easily reproduce or alter base training |
| Architecture Only | Model architecture | Requires training from scratch; no pre-trained knowledge accessible |
"""
print(comparison_table)

# %%
# TODO: 3?5 sentence comparative paragraph
comparative_paragraph = """Fully Open LLMs offer unparalleled flexibility, allowing users complete freedom to inspect, modify, and retrain every aspect of the model. Weights Released models provide the advantage of pre-trained capabilities for fine-tuning and deployment, though without full access to the original training process or data. In contrast, Architecture Only models are the least open, demanding complete re-training and significant resources to achieve useful performance, primarily serving as blueprints for independent development."""
print(comparative_paragraph)

# %%
# TODO: 1?2 sentence healthcare prompt answer
healthcare_prompt_answer = """For healthcare compliance and retraining on clinical data, a 'Fully Open' LLM is ideal as it allows complete transparency, auditing, and control over data usage and model modifications to meet stringent regulatory requirements."""
print(healthcare_prompt_answer)

# %% [markdown]
# ## Exercise 2: License Check for SaaS Use
# **Use:** HF model pages; permissive vs. copyleft; commercial clauses; restrictions (MAU caps, attribution, export controls).
#
# **Step-by-step**
# 1) Select two HF models (e.g., Mistral-7B-Instruct, Llama-2-7b-chat-hf) and note URLs.
# 2) Locate the License field and copy the name.
# 3) Determine if commercial use is allowed/restricted/prohibited; note conditions.
# 4) Identify extra restrictions (MAU caps, attribution, export/geography).
# 5) Build the markdown checklist with your findings.
#
# **Deliverables:** model names + URLs + completed checklist.

# %%
# TODO: record model metadata from the HF pages
license_checklist = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3",
        "license": "Apache 2.0",
        "commercial_use": "Yes",
        "restrictions": ["Attribution (Apache 2.0)", "Trademark use restrictions"],
    },
    {
        "model": "meta-llama/Llama-2-7b-chat-hf",
        "url": "https://huggingface.co/meta-llama/Llama-2-7b-chat-hf",
        "license": "Llama 2 Community License",
        "commercial_use": "Conditional",
        "restrictions": ["Attribution (Llama 2 License)", "MAU cap (700 million MAU for commercial use without special license)", "No use for improving other LLMs", "Export controls"],
    },
]
license_checklist

# %% [markdown]
# ### Checklist template (fill and keep in markdown)
# - [x] **Model 1: mistralai/Mistral-7B-Instruct-v0.3**
#   - Type of license:
#     - [x] Apache 2.0
#   - Commercial use allowed:
#     - [x] Yes
#   - Restrictions:
#     - [x] Attribution (Apache 2.0)
#     - [x] Trademark use restrictions
# - [x] **Model 2: meta-llama/Llama-2-7b-chat-hf**
#   - Type of license:
#     - [x] Llama 2 Community License
#   - Commercial use allowed:
#     - [x] Conditional
#   - Restrictions:
#     - [x] Attribution (Llama 2 License)
#     - [x] MAU cap (700 million MAU for commercial use without special license)
#     - [x] No use for improving other LLMs
#     - [x] Export controls

# %% [markdown]
# ## Exercise 3: LLM Matchmaker Challenge
# **Use:** CPU inference, low-end laptops, multilingual needs; HF filters; size <=7B; benchmarks (BoolQ, GSM8K, FLORES-200).
#
# **Step-by-step**
# 1) Analyze team needs (LegalTech CPU logic; EdTech math/logic low-end; Global NGO multilingual >=5 langs).
# 2) Apply HF filters (cpu/quantized, logic/math/multilingual tags, size <=7B).
# 3) List 3?5 candidates per team with params/arch/quantization/benchmarks.
# 4) Compare top 2 per team and pick the best model with justification.
# 5) Fill the table with your picks.
#
# **Deliverables:** filter summary + filled picks table.

# %%
# TODO: jot down search filters or URLs for each team
filters_by_team = {
    "LegalTech": ["text-generation", "quantized (GGUF)", "logic/reasoning tag", "<=7B params", "CPU-friendly"],
    "EdTech": ["math/reasoning tag", "quantized (GGUF)", "<=4B params", "low-resource/mobile-friendly"],
    "Global NGO": ["multilingual tag", "quantized (GGUF)", "<=7B params", "CPU-friendly"],
}
filters_by_team

# %%
# TODO: candidate lists per team (3?5 each)
candidates_by_team = {
    "LegalTech": [
        {"model": "OpenHermes-2.5-Mistral-7B", "params_b": "7B", "arch": "Mistral", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Good reasoning, chat"},
        {"model": "mistralai/Mistral-7B-Instruct-v0.3", "params_b": "7B", "arch": "Mistral", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Strong general purpose, good logic"},
        {"model": "NousResearch/Hermes-2-Pro-Mistral-7B", "params_b": "7B", "arch": "Mistral", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Function calling, reasoning"}
    ],
    "EdTech": [
        {"model": "microsoft/Phi-2", "params_b": "2.7B", "arch": "Transformer", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Strong reasoning for size, good math"},
        {"model": "TinyLlama/TinyLlama-1.1B-Chat-v1.0", "params_b": "1.1B", "arch": "Llama", "optimization": "GGUF (Q4_0)", "benchmarks": "Very small, efficient"},
        {"model": "Qwen/Qwen1.5-1.8B-Chat", "params_b": "1.8B", "arch": "Qwen", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Good general abilities for size, coding"}
    ],
    "Global NGO": [
        {"model": "bigscience/mt0-base", "params_b": "3.7B", "arch": "T5", "optimization": "PyTorch", "benchmarks": "Excellent multilingual performance"},
        {"model": "mistralai/Mistral-7B-Instruct-v0.3", "params_b": "7B", "arch": "Mistral", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Decent multilingual, good instruction following"},
        {"model": "Xenova/Llama-2-7b-chat-hf-gguf", "params_b": "7B", "arch": "Llama", "optimization": "GGUF (Q4_K_M)", "benchmarks": "Widely used, good multilingual support"}
    ],
}
candidates_by_team

# %%
# TODO: final picks table (keep markdown formatting)
matchmaker_table = """| Team | Needs | Your Pick |
| --- | --- | --- |
| LegalTech | Fast model for logic-heavy chatbot on CPU | **OpenHermes-2.5-Mistral-7B** (Strong reasoning capabilities due to fine-tuning, available in efficient GGUF for CPU) |
| EdTech | Logic/math-focused LLM on low-end laptops | **microsoft/Phi-2** (Exceptional reasoning for its small 2.7B size, highly suitable for low-resource environments) |
| Global NGO | Model that speaks 5+ languages well | **bigscience/mt0-base** (Specifically trained for multilingual tasks, providing robust language capabilities for global use) |"""
print(matchmaker_table)

# %% [markdown]
# ## Exercise 4: Local Readiness Audit
# **Use:** RAM/disk/OS; llama.cpp requirements (AVX/SSE, cmake/make/gcc/clang); quantized formats (GGUF).
#
# **Step-by-step**
# 1) Gather system specs (RAM, free disk, OS type/version).
# 2) Fill the audit table and mark ?/?.
# 3) Check llama.cpp readiness (instruction sets, compilers, build tools).
# 4) Identify upgrade needs for each ?.
#
# **Deliverables:** filled table + upgrade summary.

# %%
# TODO: your measured system specs (Example values, replace with your actual specs)
system_specs = {
    "ram_gb": "16 GB",
    "free_disk_gb": "200 GB",
    "os": "Ubuntu 22.04 LTS",
}
system_specs

# %%
# TODO: readiness table (keep markdown formatting)
readiness_table = """| Requirement | Your System Specs (Example) | Meets Requirement? |
| --- | --- | --- |
| RAM (>= 16 GB) | 16 GB | Yes |
| Free Disk Space (>= 40 GB) | 200 GB | Yes |
| OS (Linux/WSL2) | Ubuntu 22.04 LTS | Yes |"""
print(readiness_table)

# %%
# TODO: llama.cpp readiness notes (Example values, replace with your actual findings)
llama_cpp_readiness = {
    "cpu_instruction_support": "AVX2",
    "tooling": ["cmake", "gcc/clang"],
    "other_requirements": "CUDA for GPU acceleration (optional)",
}
llama_cpp_readiness

# %%
# TODO: upgrade or mitigation actions (Example values, replace with your actual needs)
upgrade_actions = [
    "Ensure `build-essential` is installed for gcc/g++",
    "Install `cmake` if not already present",
    "Verify AVX2 support for optimal CPU performance",
    "Consider adding a dedicated GPU for faster inference if performance is critical",
]
upgrade_actions

# %% [markdown]
# ## Exercise 5: Benchmark-Based Model Explorer
# **Use:** Open LLM Leaderboard; HellaSwag and MMLU scores; license types; use-case mapping.
#
# **Step-by-step**
# 1) Pick three models from the leaderboard with different strengths (high HellaSwag, high MMLU, balanced).
# 2) Record HellaSwag, MMLU, license, and ideal use case.
# 3) Fill the comparison table.
# 4) Optional: 1?2 sentence reflection on why benchmarks matter.
# 5) Quiz-style reflection: write 3 short Q&A items about choosing models for different constraints.
#
# **Deliverables:** model list + filled table + quiz-style reflection (+ optional reflection paragraph).

# %%
# TODO: leaderboard picks
leaderboard_models = [
    {
        "model": "mistralai/Mixtral-8x7B-Instruct-v0.1",
        "url": "https://huggingface.co/mistralai/Mixtral-8x7B-Instruct-v0.1",
        "hellaswag": "86.68",
        "mmlu": "78.85",
        "license": "Apache 2.0",
        "ideal_use_case": "Complex instruction following, general purpose chat, code generation"
    },
    {
        "model": "meta-llama/Llama-2-70b-chat-hf",
        "url": "https://huggingface.co/meta-llama/Llama-2-70b-chat-hf",
        "hellaswag": "83.4",
        "mmlu": "68.9",
        "license": "Llama 2 Community License",
        "ideal_use_case": "General purpose chat, content generation, fine-tuning for specific applications"
    },
    {
        "model": "Qwen/Qwen1.5-7B-Chat",
        "url": "https://huggingface.co/Qwen/Qwen1.5-7B-Chat",
        "hellaswag": "82.7",
        "mmlu": "70.9",
        "license": "Tongyi Qianwen RESEARCH LICENSE AGREEMENT",
        "ideal_use_case": "Multilingual applications, coding, creative writing"
    },
]
leaderboard_models

# %%
# TODO: comparison table (keep markdown formatting)
benchmark_table = """| Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
| --- | --- | --- | --- | --- |
| mistralai/Mixtral-8x7B-Instruct-v0.1 | 86.68 | 78.85 | Apache 2.0 | Complex instruction following, general purpose chat, code generation |
| meta-llama/Llama-2-70b-chat-hf | 83.4 | 68.9 | Llama 2 Community License | General purpose chat, content generation, fine-tuning for specific applications |
| Qwen/Qwen1.5-7B-Chat | 82.7 | 70.9 | Tongyi Qianwen RESEARCH LICENSE AGREEMENT | Multilingual applications, coding, creative writing |"""
print(benchmark_table)

# %% [markdown]
# ### Optional reflection
# 1?2 sentences on why benchmarks?not hype?should guide model choice.

# %%
# TODO: quiz-style reflection (3 short Q&A items on model selection)
quiz_reflection = [
    {"question": "Why might a model with a lower MMLU score still be preferable for a specific task?", "answer": "Because MMLU measures general world knowledge and reasoning, a lower score might be acceptable if the model excels in a specialized area, like creative writing or code generation, or if it's much smaller and faster for a specific domain."},
    {"question": "What's a key consideration when choosing between Apache 2.0 and a more restrictive license like Llama 2 Community License for commercial use?", "answer": "Apache 2.0 is generally more permissive for commercial use, often requiring only attribution. The Llama 2 license has MAU caps and other restrictions that could complicate large-scale commercial deployment or integration with other LLMs."},
    {"question": "When should HellaSwag be a primary benchmark for model selection?", "answer": "HellaSwag assesses common sense reasoning. It should be a primary benchmark when the application requires the LLM to understand and predict plausible outcomes in everyday situations, such as in chatbots or conversational AI that need to sound natural and coherent."},
]
quiz_reflection

# %% [markdown]
# ## Exercise 6: Cloud vs. Local Deployment Plan
# **Use:** local vs. cloud cost/latency/scalability/security/maintenance; optional Colab timing.
#
# **Step-by-step**
# 1) Draft 5 bullets pairing local vs. cloud pros/cons.
# 2) Optional: run a 7B model on Colab; note model and response time.
# 3) Summarize Colab observation if you ran it.
#
# **Deliverables:** 5 bullets; optional Colab report (model + time).

# %%
# TODO: 5 bullets mixing pros/cons (one line each)
pros_and_cons = [
    "Local Deployment: Pro - Full data control & privacy; Con - High upfront hardware cost.",
    "Cloud Deployment: Pro - Scalability and flexibility; Con - Data security concerns & vendor lock-in.",
    "Local Deployment: Pro - Lower latency for local users; Con - Complex maintenance and updates.",
    "Cloud Deployment: Pro - Reduced operational overhead; Con - Potentially higher long-term costs.",
    "Local Deployment: Pro - Customizable hardware for specific needs; Con - Limited geographic reach for users."
]
pros_and_cons

# %%
# Optional: Colab timing note
colab_run = {
    "model_tested": "",
    "response_time_seconds": "",
    "notes": "This section is optional, as running a 7B model on Colab and timing its response would require executing code not directly requested by the prompt. If execution is desired, a specific model and timing mechanism would need to be implemented."
}
colab_run
